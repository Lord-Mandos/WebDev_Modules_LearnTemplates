# %% [markdown]
# ># **04 <span style="color:#6be7fa">CSS</span> - Projects**

# %% [markdown]
# > ## **Triangle Layout Design**
#
# ![image.png](attachment:image.png)
#
# [Triangle Layout Design](https://youtu.be/K81nTBjlmBM?si=e7Rxguh4O7MTyo5-)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Animated Login Form Dark**
#
# ![image.png](attachment:image.png)
#
# [Animated Login Form Dark](https://youtu.be/cxm5bCCa9OA?si=VoYc1caOvsyrfNmO)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Animated Login Form Light**
#
# ![image.png](attachment:image.png)
#
# [Animated Login Form Light](https://youtu.be/yLcal6M4t68?si=BAZXKs0S1Z0LwUqZ)

# %% [markdown]
# ***

# %% [markdown]
# >## **Button Hover Effects**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [HTML CSS Button Hover Effects](https://www.youtube.com/watch?v=CTIfi3mbgag)

# %% [markdown]
# ***

# %% [markdown]
# >## **Animated Circular Social Media Menu**
#
# * includes Vanilla Javascript
#
# ![image.png](attachment:image.png)
#
# [Animated Circular Social Media Menu](https://www.youtube.com/watch?v=Af9NqzFIEPs)

# %% [markdown]
# ***

# %% [markdown]
# >## **Digital Clock**
#
# ![image.png](attachment:image.png)
#
# [Digital Clock](https://www.youtube.com/watch?v=PigzP0D9xeg)

# %% [markdown]
# ***
