# %% [markdown]
# ># **02 <span style="color:#6be7fa">CSS</span> - Properties**

# %% [markdown]
# >## **Color**
#
# ![image.png](attachment:image.png)
#
# * color => Textfarbe
# * farben können über namen, rgb werte oder hex werte angesprochen werden

# %% [markdown]
# [Colorhunt.co](https://colorhunt.co/)
#
# [RGB Mixer](https://www.csfieldguide.org.nz/en/interactives/rgb-mixer/)

# %% [markdown]
# ***

# %% [markdown]
# >## **Fonts**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > ### **Font Size**
#
# | 1 <span style="color:#d395fc">px</span>| 1 <span style="color:#d395fc">pt</span> | 1 <span style="color:#d395fc">em</span> | 1 <span style="color:#d395fc">rem</span> |
# |:---------:|:-------------:|:--------------:|:--------------:|
# | 1 / 96th inch | 1 / 72nd inch | 100% of parent element | 100% of root HTML |
#
# em => relativ zum übergeordneten Element\
# rem => relativ zum root also zur HTML Datei

# %% [markdown]
# ***

# %% [markdown]
# > ### **Font Weight**
#
#
# | <span style="color:#d395fc">Keywords</span> | <span style="color:#d395fc">Relative to Parent</span> | <span style="color:#d395fc">number</span> |
# |:---------:|:-------------:|:--------------:|
# | normal, bold | lighter, bolder | 100 - 900 |
# | normal, bold | - 100, + 100 | light - bold |

# %% [markdown]
# ***

# %% [markdown]
# > ### **Font Family**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# falls Typeface nicht auf dem PC vorhanden, wird ein generic Fontstyle als Backup eingesetzt
#
# **serif**:      spitz zu laufende Enden an den Buchstaben\
# **sans-serif**: rechtwinklige Enden an den Buchstaben

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [Fontstyles finden](https://fonts.google.com/)
#
# Font auswählen und den link kopieren,\
# diesen dann im HTML head nach dem Styletag einsetzen.
#
# CSS Regeln werden ebenfalls durch google bereit gestellt.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ### **Alignment**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# [MDN Docs Text Alignment](https://developer.mozilla.org/en-US/docs/Web/CSS/text-align?retiredLocale=de)

# %% [markdown]
# ***

# %% [markdown]
# > ## **<span style="color:#fcba03">Quest 3</span>** Adding Font Properties

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung CSS Quest 3 Font Properties</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# > ## **Inspection**

# %%
<!-- Space for notes about Inspector -->

# %% [markdown]
# ***

# %% [markdown]
# > ## **<span style="color:#fcba03">Quest 4</span>** [Inspection Quiz](https://appbrewery.github.io/css-inspection/)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung CSS Quest 4 Inspection</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# > ## **<span style="color:#6be7fa">CSS</span> Box Model**

# %% [markdown]
# ![image.png](attachment:image.png)\
# Boxmodel im Inspector

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# ## **Div Element**
#
# unterschiedliche HTML Elemente können mit dem Content Division Element zusammengefasst werden.

# %% [markdown]
# Das Div Element ist nicht sichtbar, solange keine Styles (CSS Regeln) daran gebunden werden.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mit Pesticide und den DevTools mal über die einzelnen Elemente hovern\
# Welche Informationen können hier ausgelesen werden?
#
# Additional Tools\
# [Pesticide](https://chromewebstore.google.com/detail/pesticide-for-chrome/bakpbgckdnepkmkeaiomhmfcnejndkbi)

# %% [markdown]
# ***

# %% [markdown]
# > ## **<span style="color:#fcba03">Quest 5</span>** Box Model

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung CSS Quest 5 Box Model</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#d395fc">Project</span> Motivation Meme**
