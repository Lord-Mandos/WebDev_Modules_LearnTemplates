# %% [markdown]
# ># **01.2 <span style="color:#f5dd42">JavaScript</span> - Variables**

# %% [markdown]
# >## **Store prompt in Variable**

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Keywords for Variables**

# %% [markdown]
# ***

# %% [markdown]
# >## **Alert Variable**

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#fcba03">Quest 1</span>** Swap Variables

# %% [markdown]
# ![giphy.gif](attachment:giphy.gif) ![giphy.gif](attachment:giphy.gif)

# %%
function test() {
    var a = "3";
    var b = "8";
    
/***********Do not change the code above 👆*******/
//Write your code here:

/***********Do not change the code below 👇*******/

    console.log("a is " + a);
    console.log("b is " + b);
}

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung JS Quest 1 Swap Variables</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# >## **Regeln zur Erstellung von Variablen**
# > Sprechende Variablennamen

# %% [markdown]
# > ### **Welcher Variablenname ist nicht in JavaScript erlaubt?**
#
# - [ ] var myage = 12;
# - [ ] var my age = 12
# - [ ] var myAge = 12
# - [ ] var my_age = 12

# %% [markdown]
# ***

# %% [markdown]
# > ## **String Concatenation**
