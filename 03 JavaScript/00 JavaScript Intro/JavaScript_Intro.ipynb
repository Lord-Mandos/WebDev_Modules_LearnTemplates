# %% [markdown]
# ># **<span style="color:#f5dd42">JS</span> - JavaScript**

# %% [markdown]
# ![JS.webp](attachment:JS.webp)

# %% [markdown]
# * Live Script
# * JScript
# * ECMA Script ES
# * JavaScript
#
# >JavaScript wird von allen relevanten Browsern unterstützt
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***

# %% [markdown]
# >## **Compiler and Interpreter**
#
# [Difference Compiler and Interpreter](https://www.youtube.com/watch?v=_C5AHaS1mOA)
#
# | Compiled | Interpreted |
# |:-------------:|:--------------:|
# |  C  | JavaScript |
# | C++ | Python |
# | C# | Ruby |
# | Java | PHP |

# %% [markdown]
# ***

# %% [markdown]
# > ## **Erste Schritte mit JavaScript | alert();**
#
# mit F12 die Dev Tools öffnen und in der Konsole einen alert ausführen
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***

# %% [markdown]
# > ## **Eingabe | prompt();**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***
