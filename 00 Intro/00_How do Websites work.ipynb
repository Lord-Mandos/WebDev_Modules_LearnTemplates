# %% [markdown]
# ># **How do websites work?**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# [https://www.nslookup.io/](https://www.nslookup.io/)

# %% [markdown]
# ***

# %% [markdown]
# >## **Submarine Cables**
#
# ![image.png](attachment:image.png)
#
# [https://www.submarinecablemap.com/](https://www.submarinecablemap.com/)

# %% [markdown]
# ***

# %% [markdown]
# >## **Unterschiedliche Codefiles | HTML | CSS | JavaScript**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# HTML = Content\
# CSS = Style | Farben der Wände | Optik der Türen\
# JS = Functionality | Elektrik | Türenverhalten

# %% [markdown]
# ***

# %% [markdown]
# >## **Chrome or Firefox Developer Tools**

# %%
<!-- Space for Notes -->

# %% [markdown]
# Eigene Webseiten bauen und hosten in den kommenden Wochen

# %% [markdown]
# ***

# %% [markdown]
# >## **Static and Dynamic Websites**

# %% [markdown]
# >### **Statisch**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >### **Dynamisch**

# %% [markdown]
# ![image.png](attachment:image.png)
