# %% [markdown]
# ># **Full Stack Dev Roadmap**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***

# %% [markdown]
# [52 Best VS Code Extensions](https://www.consolvis.de/en/blog/52-best-vscode-extensions-to-improve-your-productivity-in-2021/)
