# %% [markdown]
# ># **01 <span style="color:#fa8423">HTML</span> - <span style="color:#fa8423">H</span>yper <span style="color:#fa8423">T</span>ext <span style="color:#fa8423">M</span>arkup <span style="color:#fa8423">L</span>anguage**

# %% [markdown]
# Beschreibt die Struktur und den Inhalt einer Website
#
# Hyper Text => [www.w3schools.com/html](https://www.w3schools.com/html/default.asp)
#
# Markup Language =>  [Auszeichnungssprache](https://de.wikipedia.org/wiki/Auszeichnungssprache)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ***

# %% [markdown]
# >## **Heading Tag**

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#fcba03">Quest 1</span>** Adjust Headings like displayed in the associated picture
#
#     -> Live Preview Plugin installieren

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung HTML Quest Heading</b>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# [Morzilla Developer Network Web Docs - MDN Docs](https://developer.mozilla.org/en-US/docs/Web/HTML/Element/Heading_Elements)

# %% [markdown]
# ***

# %% [markdown]
# >## **Paragraph Element**

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#fcba03">Quest 2</span>** Place Paragraph Tags so we receive three clean paragraphs.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung HTML Quest 2 Paragraph</b>
# </div>

# %% [markdown]
# [Lorem Ipsum Generator](https://www.loremipsum.de/)

# %% [markdown]
# [Bro Ipsum Generator](https://www.broipsum.com/)

# %% [markdown]
# ***

# %% [markdown]
# >## **Void Paragraph**

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#fcba03">Quest 3</span>** Void Elements Anpassung des Textes so, dass dieser wie die Vorlage aussieht.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Lösung HTML Quest 3 Void Elements | Paragraphs | Heading </b>
# </div>

# %% [markdown]
# [Diff Checker](https://www.diffchecker.com/)
#
# Validate Code against Solution here

# %% [markdown]
# ***

# %% [markdown]
# >## **<span style="color:#d395fc">Project</span> Game Rating Website**
